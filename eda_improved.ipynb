# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('obesity_cleaned_improved.csv')

# %%
df.columns
# Out:
# Index(['age', 'height_rounded', 'weight_rounded', 'veges_freq',
#        'main_meals_num', 'daily_water_consumption', 'physical_activity_freq',
#        'tech_devices_usage', 'high_kcal_food', 'transport_used',
#        'snacks_consuming', 'smoking', 'kcal_monitoring', 'alcohol_consumption',
#        'gender', 'bmi'],
#       dtype='object')

# %%
df.describe()
# Out:
#                age  height_rounded  weight_rounded          bmi
# count  2111.000000     2111.000000     2111.000000  2111.000000
# mean     24.623875        1.701620       86.586035    25.320514
# std       6.376622        0.093368       26.191163     7.134171
# min      14.000000        1.450000       39.000000    11.893443
# 25%      20.000000        1.630000       65.470000    20.231501
# 50%      23.000000        1.700000       83.000000    24.677143
# 75%      26.000000        1.770000      107.430000    31.752273
# max      61.000000        1.980000      173.000000    46.256684

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 16 columns):
# age                        2111 non-null int64
# height_rounded             2111 non-null float64
# weight_rounded             2111 non-null float64
# veges_freq                 2111 non-null object
# main_meals_num             2111 non-null object
# daily_water_consumption    2111 non-null object
# physical_activity_freq     2111 non-null object
# tech_devices_usage         2111 non-null object
# high_kcal_food             2111 non-null object
# transport_used             2111 non-null object
# snacks_consuming           2111 non-null object
# smoking                    2111 non-null object
# kcal_monitoring            2111 non-null object
# alcohol_consumption        2111 non-null object
# gender                     2111 non-null object
# bmi                        2111 non-null float64
# dtypes: float64(3), int64(1), object(12)
# memory usage: 264.0+ KB

# %%
sns.distplot(df['bmi'], bins=50)

# %%
sns.distplot(df['age'], bins=50)

# %%
print("Skewness: %f" % df['bmi'].skew())
print("Kurtosis: %f" % df['bmi'].kurt())
# Out:
# Skewness: 0.187080
# Kurtosis: -0.779374

# %%
df.plot.scatter(x='age', y='bmi')

# %%
df.columns
# Out:
# Index(['age', 'height_rounded', 'weight_rounded', 'veges_freq',
#        'main_meals_num', 'daily_water_consumption', 'physical_activity_freq',
#        'tech_devices_usage', 'high_kcal_food', 'transport_used',
#        'snacks_consuming', 'smoking', 'kcal_monitoring', 'alcohol_consumption',
#        'gender', 'bmi'],
#       dtype='object')

# %%
df_cat = df[['veges_freq', 'main_meals_num', 'daily_water_consumption', 'physical_activity_freq',
             'tech_devices_usage', 'high_kcal_food', 'transport_used','snacks_consuming', 'smoking',
             'kcal_monitoring', 'alcohol_consumption', 'gender']]

# %%
df_num = df[['age', 'bmi']]

# %%
df_num.corr()
# Out:
#           age       bmi
# age  1.000000  0.233341
# bmi  0.233341  1.000000

# %%
df_num.boxplot()

# %%
for column in df_cat.columns:
    sns.boxplot(x=column, y='bmi', data=df)
    plt.show()

# %%
sns.pairplot(df_num)
